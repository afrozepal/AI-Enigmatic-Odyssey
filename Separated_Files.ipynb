# %%
###################     BFS
from collections import deque
import time
#dictionary for naming , child number with i_ch gloabl at line 1
ch = {}
global i_ch
i_ch=0
##matrix matching
def matrices_match(matrix1, matrix2):
    if len(matrix1) != len(matrix2) or len(matrix1[0]) != len(matrix2[0]):
        return False  # Matrices have different dimensions, so they cannot match

    for i in range(len(matrix1)):
        for j in range(len(matrix1[0])):
            if matrix1[i][j] != matrix2[i][j]:
                return False  # Corresponding elements are different, so the matrices do not match
    return True  # All corresponding elements are the same, so the matrices match

###Start for matix , zero position and print
class MATRIX:

    def __init__(self, matrix):
        self.matrix = matrix

    def printmatrix(self):
        for row in self.matrix:
            print(row)

    def zerostate(self, matrix):
        self.matrix=matrix
        for im in range(len(self.matrix)):
            for jm in range(len(self.matrix[im])):
                if self.matrix[im][jm] == 0:
                    return (im, jm)  # Return the row and column indices of the zero

## for making tree
class TreeNode:

    def __init__(self, matrix, parent=None):
        self.matrix = matrix
        self.parent = parent
        self.children = []

    def add_child(self, child_node):
        self.children.append(child_node)

######to get path
def find_goal_node(root_node, goal_matrix):
    # Perform a depth-first search to find the node corresponding to the goal matrix
    stack = [root_node]
    while stack:
        current_node = stack.pop()
        if current_node.matrix == goal_matrix:
            return current_node
        stack.extend(current_node.children)
    return None  # Goal node not found

def trace_back_to_root(goal_matrix, goal_node, root_matrix):
    path = [goal_matrix]
    current_matrix = goal_matrix
    while current_matrix != root_matrix:
        current_node = goal_node
        while current_node is not None and current_node.matrix != current_matrix:
            current_node = current_node.parent
        if current_node is None:
            # Node not found, break the loop
            break
        current_matrix = current_node.parent.matrix
        path.append(current_matrix)
    return path[::-1]  # Reverse the path to get the root-to-goal path


##  movements and storing resulatant matrix in tree ,
def move_up(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_row > 0:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row - 1][zero_column] =\
            new_matrix[zero_row - 1][zero_column], new_matrix[zero_row][zero_column]  # Swap zero with the element above it
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_down(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_row < len(matrix) - 1:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row + 1][zero_column] =\
            new_matrix[zero_row + 1][zero_column], new_matrix[zero_row][zero_column]  # Swap zero with the element below it
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_left(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_column > 0:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row][zero_column - 1] =\
            new_matrix[zero_row][zero_column - 1], new_matrix[zero_row][zero_column]  # Swap zero with the element to its left
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_right(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_column < len(matrix[0]) - 1:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row][zero_column + 1] =\
            new_matrix[zero_row][zero_column + 1], new_matrix[zero_row][zero_column]  # Swap zero with the element to its right
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

##############################################################                  MAIN
def main():
    # Taking input from the user
    s_start = input("Enter start state: ")
    s_goal = input("Enter goal state: ")
    print("Start State: ", s_start)
    print("Goal  State: ", s_goal)

    ########### start state in matrix
    # Convert the input string into a list of integers-------Start state
    num = [int(char) for char in s_start]
    while len(s_start) != 9:
        print("Invalid input: The start state must contain exactly 9 digits.")
        s_start = input("Enter start state: ")
        num = [int(char) for char in s_start]
    else:
    # Create a 3x3 matrix from the list of numbers
     matrix = [num[i:i+3] for i in range(0, len(num), 3)]


    ########### goal state in matrix
    # Convert the input string into a list of integers
    gnum = [int(char) for char in s_goal]
    while len(s_goal) != 9:
        print("Invalid input: The goal state must contain exactly 9 digits.")
        s_goal = input("Enter goal state: ")
        gnum = [int(char) for char in s_goal]
    else:
    # Create a 3x3 matrix from the list of numbers
        g_matrix = [gnum[i:i+3] for i in range(0, len(gnum), 3)]



    #initialize matrix , print
    m = MATRIX(matrix)
    print ("Start state is :  ")
    m.printmatrix()
    print ("Goal state is :  ")
    m = MATRIX(g_matrix)
    m.printmatrix()
    print ("\n\n\n\n")
    start_time = time.time()
    #, get state of zero or space in  start state 8 game
    zero_state = m.zerostate(matrix)
    zero_row, zero_column = zero_state

    #start state matrix set as root Node , and to traverse in order , BFS , making a queue
    root = TreeNode(matrix)
    visited = set()
    visited.add(tuple(map(tuple, matrix)))
    queue = deque([root])  # Using a queue for BFS
    step = 0
    print(" ============= USING BFS ALGORITHM =============")
    print("Traversal of Nodes using BFS from start to goal is : ")
    # Print initial state
    print("Step", step, ":")
    for row in matrix:
        print(row)

    while queue:
        # Dequeue the first node from the queue
        current_child = queue.popleft()
        pass_matrix = current_child.matrix
        parent_node = current_child

        if matrices_match(pass_matrix, g_matrix):
            break

        zero_state = m.zerostate(pass_matrix)
        zero_row, zero_column = zero_state

        # Attempt each movement in a specified order of L ,U ,D,R
        check_matrix = move_left(pass_matrix, zero_row, zero_column, parent_node)   # LEFT
        if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
            child_node = TreeNode(check_matrix, parent=current_child)
            current_child.add_child(child_node)
            visited.add(tuple(map(tuple, check_matrix)))
            queue.append(child_node)
            # Increment step counter
            step += 1
            print("Step", step, ":")
            for row in check_matrix:
                print(row)
            # If a goal state is found, break out of the loop
            if matrices_match(check_matrix, g_matrix):
                break


        check_matrix = move_up(pass_matrix, zero_row, zero_column, parent_node) ### UP
        if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
            child_node = TreeNode(check_matrix, parent=current_child)
            current_child.add_child(child_node)
            visited.add(tuple(map(tuple, check_matrix)))
            queue.append(child_node)
            # Increment step counter
            step += 1
            print("Step", step, ":")
            for row in check_matrix:
                print(row)
            # If a goal state is found, break out of the loop
            if matrices_match(check_matrix, g_matrix):
                break

        check_matrix = move_right(pass_matrix, zero_row, zero_column, parent_node)   ## DOWN
        if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
            child_node = TreeNode(check_matrix, parent=current_child)
            current_child.add_child(child_node)
            visited.add(tuple(map(tuple, check_matrix)))
            queue.append(child_node)
            # Increment step counter
            step += 1
            print("Step", step, ":")
            for row in check_matrix:
                print(row)
            # If a goal state is found, break out of the loop
            if matrices_match(check_matrix, g_matrix):
                break

        check_matrix = move_down(pass_matrix, zero_row, zero_column, parent_node)  # RIGHT
        if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
            child_node = TreeNode(check_matrix, parent=current_child)
            current_child.add_child(child_node)
            visited.add(tuple(map(tuple, check_matrix)))
            queue.append(child_node)
            # Increment step counter
            step += 1
            print("Step", step, ":")
            for row in check_matrix:
                print(row)
            # If a goal state is found, break out of the loop
            if matrices_match(check_matrix, g_matrix):
                break


    print("Path Cost of traversal is : ", step)
    print("Nodes Visited : ", step+1)

    print("Path from start to goal : ")
    goal_matrix = g_matrix
    root_matrix =matrix
    goal_node = find_goal_node(root, goal_matrix)

    if goal_node is None:
        print("Goal node not found in the tree.")
        return

    # Trace back from the goal node to the root
    path_to_root = trace_back_to_root(goal_matrix, goal_node, root_matrix)
    x=0
    for i, matrix in enumerate(path_to_root):
        print("Step", i)
        x=i
        for row in matrix:
            print(row)
        print()

    print("Path Cost is : ", x)
    print("Nodes Visited : ", x+1)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print("BFS Time:", elapsed_time, "seconds")

if __name__ == "__main__":
    main()

# %%
import time
#dictionary for naming , child number with i_ch gloabl at line 1
ch = {}
global i_ch
i_ch=0
##matrix matching
def matrices_match(matrix1, matrix2):
    if len(matrix1) != len(matrix2) or len(matrix1[0]) != len(matrix2[0]):
        return False  # Matrices have different dimensions, so they cannot match

    for i in range(len(matrix1)):
        for j in range(len(matrix1[0])):
            if matrix1[i][j] != matrix2[i][j]:
                return False  # Corresponding elements are different, so the matrices do not match
    return True  # All corresponding elements are the same, so the matrices match

###Start for matix , zero position and print
class MATRIX:

    def __init__(self, matrix):
        self.matrix = matrix

    def printmatrix(self):
        for row in self.matrix:
            print(row)

    def zerostate(self, matrix):
        self.matrix=matrix
        for im in range(len(self.matrix)):
            for jm in range(len(self.matrix[im])):
                if self.matrix[im][jm] == 0:
                    return (im, jm)  # Return the row and column indices of the zero


###
######to get path
def find_goal_node(root_node, goal_matrix):
    # Perform a depth-first search to find the node corresponding to the goal matrix
    stack = [root_node]
    while stack:
        current_node = stack.pop()
        if current_node.matrix == goal_matrix:
            return current_node
        stack.extend(current_node.children)
    return None  # Goal node not found

def trace_back_to_root(goal_matrix, goal_node, root_matrix):
    path = [goal_matrix]
    current_matrix = goal_matrix
    while current_matrix != root_matrix:
        current_node = goal_node
        while current_node is not None and current_node.matrix != current_matrix:
            current_node = current_node.parent
        if current_node is None:
            # Node not found, break the loop
            break
        current_matrix = current_node.parent.matrix
        path.append(current_matrix)
    return path[::-1]  # Reverse the path to get the root-to-goal path

## for making tree
class TreeNode:

    def __init__(self, matrix, parent=None):
        self.matrix = matrix
        self.parent = parent
        self.children = []

    def add_child(self, child_node):
        self.children.append(child_node)



##  movements and storing resulatant matrix in tree ,
def move_up(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_row > 0:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row - 1][zero_column] =\
            new_matrix[zero_row - 1][zero_column], new_matrix[zero_row][zero_column]  # Swap zero with the element above it
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_down(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_row < len(matrix) - 1:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row + 1][zero_column] =\
            new_matrix[zero_row + 1][zero_column], new_matrix[zero_row][zero_column]  # Swap zero with the element below it
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_left(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_column > 0:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row][zero_column - 1] =\
            new_matrix[zero_row][zero_column - 1], new_matrix[zero_row][zero_column]  # Swap zero with the element to its left
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_right(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_column < len(matrix[0]) - 1:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row][zero_column + 1] =\
            new_matrix[zero_row][zero_column + 1], new_matrix[zero_row][zero_column]  # Swap zero with the element to its right
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

##############################################################                  MAIN
def main():
    # Taking input from the user
    s_start = input("Enter start state: ")
    s_goal = input("Enter goal state: ")
    print("Start State: ", s_start)
    print("Goal  State: ", s_goal)

    # Convert the input string into a list of integers for the start state
    num = [int(char) for char in s_start]
    while len(s_start) != 9:
        print("Invalid input: The start state must contain exactly 9 digits.")
        s_start = input("Enter start state: ")
        num = [int(char) for char in s_start]
    else:
        # Create a 3x3 matrix from the list of numbers
        matrix = [num[i:i + 3] for i in range(0, len(num), 3)]

    # Convert the input string into a list of integers for the goal state
    gnum = [int(char) for char in s_goal]
    while len(s_goal) != 9:
        print("Invalid input: The goal state must contain exactly 9 digits.")
        s_goal = input("Enter goal state: ")
        gnum = [int(char) for char in s_goal]
    else:
        # Create a 3x3 matrix from the list of numbers
        g_matrix = [gnum[i:i + 3] for i in range(0, len(gnum), 3)]

    # Initialize matrices and print
    m = MATRIX(matrix)
    print("Start state is :  ")
    m.printmatrix()
    print("Goal state is :  ")
    m = MATRIX(g_matrix)
    m.printmatrix()
    print("\n\n\n\n")
    start_time = time.time()
    # Get position of zero or space in the start state
    zero_state = m.zerostate(matrix)
    zero_row, zero_column = zero_state

    # Initialize root Node and DFS stack
    root = TreeNode(matrix)
    visited = set()
    visited.add(tuple(map(tuple, matrix)))
    stack = [root]  # Using a list as a stack for DFS
    step = 0
    goal = False  # Flag to break all while loops when the destination is reached

    print(" ============= USING DFS ALGORITHM =============")
    print("Traversal of Nodes using DFS from start to goal is : ")

    # Print initial state
    print("Step", step, ":")
    for row in matrix:
        print(row)

    while stack and not goal:
        current_child = stack[-1]
        pass_matrix = current_child.matrix
        parent_node = current_child

        if matrices_match(pass_matrix, g_matrix):
            goal = True
            break

        zero_state = m.zerostate(pass_matrix)
        zero_row, zero_column = zero_state

        # Move Left if possible
        check_matrix = move_left(pass_matrix, zero_row, zero_column, parent_node)  # Left
        if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
            child_node = TreeNode(check_matrix, parent=current_child)
            current_child.add_child(child_node)
            visited.add(tuple(map(tuple, check_matrix)))
            stack.append(child_node)
            # Increment step counter
            step += 1
            print("Moving left ")
            print("Step", step, ":")
            for row in check_matrix:
                print(row)
            # If a goal state is found, break out of the loop
            if matrices_match(check_matrix, g_matrix):
                goal = True
                break
        else:
            # Move Up if possible
            check_matrix = move_up(pass_matrix, zero_row, zero_column, parent_node)  # Up
            if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
                child_node = TreeNode(check_matrix, parent=current_child)
                current_child.add_child(child_node)
                visited.add(tuple(map(tuple, check_matrix)))
                stack.append(child_node)
                # Increment step counter
                step += 1
                print("Moving up ")
                print("Step", step, ":")
                for row in check_matrix:
                    print(row)
                # If a goal state is found, break out of the loop
                if matrices_match(check_matrix, g_matrix):
                    goal = True
                    break
            else:
                # Move Right if possible
                check_matrix = move_right(pass_matrix, zero_row, zero_column, parent_node)  # Right
                if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
                    child_node = TreeNode(check_matrix, parent=current_child)
                    current_child.add_child(child_node)
                    visited.add(tuple(map(tuple, check_matrix)))
                    stack.append(child_node)
                    # Increment step counter
                    step += 1
                    print("Moving right ")
                    print("Step", step, ":")
                    for row in check_matrix:
                        print(row)
                    # If a goal state is found, break out of the loop
                    if matrices_match(check_matrix, g_matrix):
                        goal = True
                        break
                else:
                    # Move Down if possible
                    check_matrix = move_down(pass_matrix, zero_row, zero_column, parent_node)  # Down
                    if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
                        child_node = TreeNode(check_matrix, parent=current_child)
                        current_child.add_child(child_node)
                        visited.add(tuple(map(tuple, check_matrix)))
                        stack.append(child_node)
                        # Increment step counter
                        step += 1
                        print("Moving down ")
                        print("Step", step, ":")
                        for row in check_matrix:
                            print(row)
                        # If a goal state is found, break out of the loop
                        if matrices_match(check_matrix, g_matrix):
                            goal = True
                            break
                    else:
                        stack.pop()


    print("Path Cost of traversal is : ", step)
    print("Nodes Visited : ", step+1)

    print("Path from start to goal : ")
    goal_matrix = g_matrix
    root_matrix =matrix
    goal_node = find_goal_node(root, goal_matrix)

    if goal_node is None:
        print("Goal node not found in the tree.")
        return

    # Trace back from the goal node to the root
    path_to_root = trace_back_to_root(goal_matrix, goal_node, root_matrix)
    x=0
    for i, matrix in enumerate(path_to_root):
        print("Step", i)
        x=i
        for row in matrix:
            print(row)
        print()

    print("Path Cost is : ", x)
    print("Nodes Visited : ", x+1)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print("BFS Time:", elapsed_time, "seconds")

if __name__ == "__main__":
    main()

# %%
import time
#dictionary for naming , child number with i_ch gloabl at line 1
ch = {}
global i_ch
i_ch=0
##matrix matching
def matrices_match(matrix1, matrix2):
    if len(matrix1) != len(matrix2) or len(matrix1[0]) != len(matrix2[0]):
        return False  # Matrices have different dimensions, so they cannot match

    for i in range(len(matrix1)):
        for j in range(len(matrix1[0])):
            if matrix1[i][j] != matrix2[i][j]:
                return False  # Corresponding elements are different, so the matrices do not match
    return True  # All corresponding elements are the same, so the matrices match

###Start for matix , zero position and print
class MATRIX:

    def __init__(self, matrix):
        self.matrix = matrix

    def printmatrix(self):
        for row in self.matrix:
            print(row)

    def zerostate(self, matrix):
        self.matrix=matrix
        for im in range(len(self.matrix)):
            for jm in range(len(self.matrix[im])):
                if self.matrix[im][jm] == 0:
                    return (im, jm)  # Return the row and column indices of the zero


###
######to get path
def find_goal_node(root_node, goal_matrix):
    # Perform a depth-first search to find the node corresponding to the goal matrix
    stack = [root_node]
    while stack:
        current_node = stack.pop()
        if current_node.matrix == goal_matrix:
            return current_node
        stack.extend(current_node.children)
    return None  # Goal node not found

def trace_back_to_root(goal_matrix, goal_node, root_matrix):
    path = [goal_matrix]
    current_matrix = goal_matrix
    while current_matrix != root_matrix:
        current_node = goal_node
        while current_node is not None and current_node.matrix != current_matrix:
            current_node = current_node.parent
        if current_node is None:
            # Node not found, break the loop
            break
        current_matrix = current_node.parent.matrix
        path.append(current_matrix)
    return path[::-1]  # Reverse the path to get the root-to-goal path

## for making tree
class TreeNode:

    def __init__(self, matrix, parent=None):
        self.matrix = matrix
        self.parent = parent
        self.children = []

    def add_child(self, child_node):
        self.children.append(child_node)



##  movements and storing resulatant matrix in tree ,
def move_up(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_row > 0:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row - 1][zero_column] =\
            new_matrix[zero_row - 1][zero_column], new_matrix[zero_row][zero_column]  # Swap zero with the element above it
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_down(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_row < len(matrix) - 1:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row + 1][zero_column] =\
            new_matrix[zero_row + 1][zero_column], new_matrix[zero_row][zero_column]  # Swap zero with the element below it
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_left(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_column > 0:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row][zero_column - 1] =\
            new_matrix[zero_row][zero_column - 1], new_matrix[zero_row][zero_column]  # Swap zero with the element to its left
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_right(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_column < len(matrix[0]) - 1:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row][zero_column + 1] =\
            new_matrix[zero_row][zero_column + 1], new_matrix[zero_row][zero_column]  # Swap zero with the element to its right
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node)  # Pass the parent node when creating the child node
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

##############################################################                  MAIN
def main():
    # Taking input from the user
    s_start = input("Enter start state: ")
    s_goal = input("Enter goal state: ")
    print("Start State: ", s_start)
    print("Goal  State: ", s_goal)

    # Convert the input string into a list of integers for the start state
    num = [int(char) for char in s_start]
    while len(s_start) != 9:
        print("Invalid input: The start state must contain exactly 9 digits.")
        s_start = input("Enter start state: ")
        num = [int(char) for char in s_start]
    else:
        # Create a 3x3 matrix from the list of numbers
        matrix = [num[i:i + 3] for i in range(0, len(num), 3)]

    # Convert the input string into a list of integers for the goal state
    gnum = [int(char) for char in s_goal]
    while len(s_goal) != 9:
        print("Invalid input: The goal state must contain exactly 9 digits.")
        s_goal = input("Enter goal state: ")
        gnum = [int(char) for char in s_goal]
    else:
        # Create a 3x3 matrix from the list of numbers
        g_matrix = [gnum[i:i + 3] for i in range(0, len(gnum), 3)]

    # Initialize matrices and print
    m = MATRIX(matrix)
    print("Start state is :  ")
    m.printmatrix()
    print("Goal state is :  ")
    m = MATRIX(g_matrix)
    m.printmatrix()
    print("\n\n\n\n")
    start_time = time.time()
    # Get position of zero or space in the start state
    zero_state = m.zerostate(matrix)
    zero_row, zero_column = zero_state

    depth_i = int(input("Enter the initial depth you wanna check at: "))
    depth_x=0
    # Initialize root Node and DFS stack
    root = TreeNode(matrix)
    visited = set()
    visited.add(tuple(map(tuple, matrix)))
    stack = [root]  # Using a list as a stack for DFS
    step = 0
    goal = False  # Flag to break all while loops when the destination is reached

    print(" ============= USING IDS ALGORITHM =============")
    print("Traversal of Nodes using IDS from start to goal is : ")

    # # Print initial state
    # print("Step", step, ":")
    # for row in matrix:
    #     print(row)

    i_while=False

    while not i_while:
        del stack
        del root
        depth_x=0
        # Initialize root Node and DFS stack
        root = TreeNode(matrix)
        visited = set()
        visited.add(tuple(map(tuple, matrix)))
        stack = [root]  # Using a list as a stack for DFS
        step = 0
        goal = False  # Flag to break all while loops when the destination is reached

         # Print initial state
        print("Step", step, ":")
        for row in matrix:
            print(row)
        while stack and not goal:
            current_child = stack[-1]
            pass_matrix = current_child.matrix
            parent_node = current_child

            ##If not found within defined depth , increase depth and iterate from start
       #     print("depth check === " , depth_x , depth_i)
            if depth_x==depth_i:
                print("============The Search has reached the defined limit of " ,depth_x)
                print("===============STARING AGIN AFTER DEPTH INCREMENT , UPDATED DEPTH IS  " ,depth_i+1)
                depth_x=0
                depth_i+=1
                step=0
                goal=True
                break


            depth_x+=1
            if matrices_match(pass_matrix, g_matrix):
                goal = True
                i_while=True
                break

            zero_state = m.zerostate(pass_matrix)
            zero_row, zero_column = zero_state

            # Move Left if possible
            check_matrix = move_left(pass_matrix, zero_row, zero_column, parent_node)  # Left
            if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
                child_node = TreeNode(check_matrix, parent=current_child)
                current_child.add_child(child_node)
                visited.add(tuple(map(tuple, check_matrix)))
                stack.append(child_node)
                # Increment step counter
                step += 1
                print("Moving left ")
                print("Step", step, ":")
                for row in check_matrix:
                    print(row)
                # If a goal state is found, break out of the loop
                if matrices_match(check_matrix, g_matrix):
                    goal = True
                    i_while=True
                    break
            else:
                # Move Up if possible
                check_matrix = move_up(pass_matrix, zero_row, zero_column, parent_node)  # Up
                if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
                    child_node = TreeNode(check_matrix, parent=current_child)
                    current_child.add_child(child_node)
                    visited.add(tuple(map(tuple, check_matrix)))
                    stack.append(child_node)
                    # Increment step counter
                    step += 1
                    print("Moving up ")
                    print("Step", step, ":")
                    for row in check_matrix:
                        print(row)
                    # If a goal state is found, break out of the loop
                    if matrices_match(check_matrix, g_matrix):
                        goal = True
                        i_while=True
                        break
                else:
                    # Move Right if possible
                    check_matrix = move_right(pass_matrix, zero_row, zero_column, parent_node)  # Right
                    if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
                        child_node = TreeNode(check_matrix, parent=current_child)
                        current_child.add_child(child_node)
                        visited.add(tuple(map(tuple, check_matrix)))
                        stack.append(child_node)
                        # Increment step counter
                        step += 1
                        print("Moving right ")
                        print("Step", step, ":")
                        for row in check_matrix:
                            print(row)
                        # If a goal state is found, break out of the loop
                        if matrices_match(check_matrix, g_matrix):
                            goal = True
                            i_while=True
                            break
                    else:
                        # Move Down if possible
                        check_matrix = move_down(pass_matrix, zero_row, zero_column, parent_node)  # Down
                        if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
                            child_node = TreeNode(check_matrix, parent=current_child)
                            current_child.add_child(child_node)
                            visited.add(tuple(map(tuple, check_matrix)))
                            stack.append(child_node)
                            # Increment step counter
                            step += 1
                            print("Moving down ")
                            print("Step", step, ":")
                            for row in check_matrix:
                                print(row)
                            # If a goal state is found, break out of the loop
                            if matrices_match(check_matrix, g_matrix):
                                goal = True
                                i_while=True
                                break
                        else:
                            stack.pop()


    print("Path Cost of traversal is : ", step)
    print("Nodes Visited : ", step+1)

    print("Path from start to goal : ")
    goal_matrix = g_matrix
    root_matrix =matrix
    goal_node = find_goal_node(root, goal_matrix)

    if goal_node is None:
        print("Goal node not found in the tree.")
        return

    # Trace back from the goal node to the root
    path_to_root = trace_back_to_root(goal_matrix, goal_node, root_matrix)
    x=0
    for i, matrix in enumerate(path_to_root):
        print("Step", i)
        x=i
        for row in matrix:
            print(row)
        print()

    print("Path Cost is : ", x)
    print("Nodes Visited : ", x+1)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print("BFS Time:", elapsed_time, "seconds")
if __name__ == "__main__":
    main()

# %%
from queue import PriorityQueue
import time
# Dictionary for naming child number with i_ch global at line 1
ch = {}
i_ch = 0

# Matrix matching
def matrices_match(matrix1, matrix2):
    if len(matrix1) != len(matrix2) or len(matrix1[0]) != len(matrix2[0]):
        return False  # Matrices have different dimensions, so they cannot match

    for i in range(len(matrix1)):
        for j in range(len(matrix1[0])):
            if matrix1[i][j] != matrix2[i][j]:
                return False  # Corresponding elements are different, so the matrices do not match
    return True  # All corresponding elements are the same, so the matrices match

# Start for matrix, zero position, and print
class MATRIX:
    def __init__(self, matrix):
        self.matrix = matrix

    def printmatrix(self):
        for row in self.matrix:
            print(row)

    def zerostate(self, matrix):
        self.matrix = matrix
        for im in range(len(self.matrix)):
            for jm in range(len(self.matrix[im])):
                if self.matrix[im][jm] == 0:
                    return (im, jm)  # Return the row and column indices of the zero
######to get path
def find_goal_node(root_node, goal_matrix):
    # Perform a depth-first search to find the node corresponding to the goal matrix
    stack = [root_node]
    while stack:
        current_node = stack.pop()
        if current_node.matrix == goal_matrix:
            return current_node
        stack.extend(current_node.children)
    return None  # Goal node not found

def trace_back_to_root(goal_matrix, goal_node, root_matrix):
    path = [goal_matrix]
    current_matrix = goal_matrix
    while current_matrix != root_matrix:
        current_node = goal_node
        while current_node is not None and current_node.matrix != current_matrix:
            current_node = current_node.parent
        if current_node is None:
            # Node not found, break the loop
            break
        current_matrix = current_node.parent.matrix
        path.append(current_matrix)
    return path[::-1]  # Reverse the path to get the root-to-goal path
# Class to represent tree nodes
class TreeNode:
    def __init__(self, matrix, parent=None, priority=0):
        self.matrix = matrix
        self.parent = parent
        self.children = []
        self.priority = priority

    def add_child(self, child_node):
        self.children.append(child_node)

    def __lt__(self, other):
        return self.priority < other.priority

# Calculate priority based on the level
def calculate_priority(node):
    priority = 0
    while node.parent:
        priority += 1
        node = node.parent
    return priority

# Movements and storing resultant matrix in the tree
def move_left(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_column > 0:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row][zero_column - 1] =\
            new_matrix[zero_row][zero_column - 1], new_matrix[zero_row][zero_column]  # Swap zero with the element to its left
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node, priority=calculate_priority(parent_node) + 1)
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_up(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_row > 0:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row - 1][zero_column] =\
            new_matrix[zero_row - 1][zero_column], new_matrix[zero_row][zero_column]  # Swap zero with the element above it
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node, priority=calculate_priority(parent_node) + 1)
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_right(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_column < len(matrix[0]) - 1:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row][zero_column + 1] =\
            new_matrix[zero_row][zero_column + 1], new_matrix[zero_row][zero_column]  # Swap zero with the element to its right
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node, priority=calculate_priority(parent_node) + 1)
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

def move_down(matrix, zero_row, zero_column, parent_node):
    global i_ch
    global ch
    if zero_row < len(matrix) - 1:
        new_matrix = [row[:] for row in matrix]  # Create a deep copy of the matrix
        new_matrix[zero_row][zero_column], new_matrix[zero_row + 1][zero_column] =\
            new_matrix[zero_row + 1][zero_column], new_matrix[zero_row][zero_column]  # Swap zero with the element below it
        ch_name = "ch" + str(i_ch)
        ch[ch_name] = TreeNode(new_matrix, parent=parent_node, priority=calculate_priority(parent_node) + 1)
        parent_node.add_child(ch[ch_name])
        i_ch += 1
        return new_matrix
    else:
        return None

# Main function to perform UCS traversal
def main():
    # Taking input from the user
    s_start = input("Enter start state: ")
    s_goal = input("Enter goal state: ")
    print("Start State: ", s_start)
    print("Goal  State: ", s_goal)

    # Convert the input string into a list of integers for the start state
    num = [int(char) for char in s_start]
    while len(s_start) != 9:
        print("Invalid input: The start state must contain exactly 9 digits.")
        s_start = input("Enter start state: ")
        num = [int(char) for char in s_start]
    else:
        # Create a 3x3 matrix from the list of numbers
        matrix = [num[i:i + 3] for i in range(0, len(num), 3)]

    # Convert the input string into a list of integers for the goal state
    gnum = [int(char) for char in s_goal]
    while len(s_goal) != 9:
        print("Invalid input: The goal state must contain exactly 9 digits.")
        s_goal = input("Enter goal state: ")
        gnum = [int(char) for char in s_goal]
    else:
        # Create a 3x3 matrix from the list of numbers
        g_matrix = [gnum[i:i + 3] for i in range(0, len(gnum), 3)]

    # Initialize matrices and print
    m = MATRIX(matrix)
    print("Start state is :  ")
    m.printmatrix()
    print("Goal state is :  ")
    m = MATRIX(g_matrix)
    m.printmatrix()
    print("\n\n\n\n")
    start_time = time.time()
    # Get position of zero or space in the start state
    zero_state = m.zerostate(matrix)
    zero_row, zero_column = zero_state

    root = TreeNode(matrix)
    visited = set()
    visited.add(tuple(map(tuple, matrix)))
    priority_queue = PriorityQueue()  # Using a priority queue for UCS
    priority_queue.put((0, root))  # Priority is the level (depth) of the node
    step = 0

    print(" ============= USING UCS ALGORITHM =============")
    print("Traversal of Nodes using UCS from start to goal is : ")
    print("Step", step, ":")
    for row in matrix:
        print(row)

    while not priority_queue.empty():

        _, current_child = priority_queue.get()  # Get the node with the lowest priority
        pass_matrix = current_child.matrix
        parent_node = current_child

        if matrices_match(pass_matrix, g_matrix):
            break

        zero_state = m.zerostate(pass_matrix)
        zero_row, zero_column = zero_state

        # Attempt each movement in a specified order of L, U, D, R
        check_matrix = move_left(pass_matrix, zero_row, zero_column, parent_node)  # LEFT
        if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
            child_node = TreeNode(check_matrix, parent=current_child)
            current_child.add_child(child_node)
            visited.add(tuple(map(tuple, check_matrix)))
            priority = calculate_priority(child_node)
            priority_queue.put((priority, child_node))
            step += 1
            print("Step", step, ":")
            for row in check_matrix:
                print(row)
            if matrices_match(check_matrix, g_matrix):
                break

        check_matrix = move_up(pass_matrix, zero_row, zero_column, parent_node)  # UP
        if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
            child_node = TreeNode(check_matrix, parent=current_child)
            current_child.add_child(child_node)
            visited.add(tuple(map(tuple, check_matrix)))
            priority = calculate_priority(child_node)
            priority_queue.put((priority, child_node))
            step += 1
            print("Step", step, ":")
            for row in check_matrix:
                print(row)
            if matrices_match(check_matrix, g_matrix):
                break

        check_matrix = move_right(pass_matrix, zero_row, zero_column, parent_node)  # RIGHT
        if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
            child_node = TreeNode(check_matrix, parent=current_child)
            current_child.add_child(child_node)
            visited.add(tuple(map(tuple, check_matrix)))
            priority = calculate_priority(child_node)
            priority_queue.put((priority, child_node))
            step += 1
            print("Step", step, ":")
            for row in check_matrix:
                print(row)
            if matrices_match(check_matrix, g_matrix):
                break

        check_matrix = move_down(pass_matrix, zero_row, zero_column, parent_node)  # DOWN
        if check_matrix is not None and tuple(map(tuple, check_matrix)) not in visited:
            child_node = TreeNode(check_matrix, parent=current_child)
            current_child.add_child(child_node)
            visited.add(tuple(map(tuple, check_matrix)))
            priority = calculate_priority(child_node)
            priority_queue.put((priority, child_node))
            step += 1
            print("Step", step, ":")
            for row in check_matrix:
                print(row)
            if matrices_match(check_matrix, g_matrix):
                break

    print("Path Cost of traversal is : ", step)
    print("Nodes Visited : ", step + 1)

    print("Path from start to goal : ")
    goal_matrix = g_matrix
    root_matrix = matrix
    goal_node = find_goal_node(root, goal_matrix)

    if goal_node is None:
        print("Goal node not found in the tree.")
        return

    # Trace back from the goal node to the root
    path_to_root = trace_back_to_root(goal_matrix, goal_node, root_matrix)
    x = 0
    for i, matrix in enumerate(path_to_root):
        print("Step", i)
        x = i
        for row in matrix:
            print(row)
        print()

    print("Path Cost is : ", x)
    print("Nodes Visited : ", x + 1)

    end_time = time.time()
    elapsed_time = end_time - start_time
    print("BFS Time:", elapsed_time, "seconds")

# Starting point of the program
if __name__ == "__main__":
    main()
